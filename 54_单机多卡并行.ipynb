# %% [markdown]
# # 1. 单机多卡并行

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 总结

# %% [markdown]
# ![image.png](attachment:image.png)
