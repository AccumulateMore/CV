# %% [markdown]
# # 1. 树叶分类竞赛技术总结

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. 总结

# %% [markdown]
# ![image.png](attachment:image.png)
